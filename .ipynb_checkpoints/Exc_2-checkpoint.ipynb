# %% [markdown]
# # Exponentialy Leaky Integrate-and-Fire Model

# %% [markdown]
# ### imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ### Generate Exponentialy Leaky Integrate-and-Fire Model

# %%
def e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT, I = 0, Alternative = False, startRange = 0, endRange = 0):
    tau_m = Rm*Cm
    Vm = np.zeros(len(time))
    IRange = []
    if (Alternative):
        for i, t in enumerate(time):
            tempRandI = random.randrange(startRange, endRange)
            IRange.append(tempRandI)
            if t > t_rest:
                Vm[i] = Vm[i-1] + (-Vm[i-1] + tempRandI*Rm) / tau_m * dt
            if Vm[i] >= Vth:
                Vm[i] += V_spike
                t_rest = t + tau_ref 
    else:
        for i, t in enumerate(time):
            IRange.append(I)
            if t > t_rest:
                Vm[i] = ( - ( Vm[i] - Vm[i-1] ) * dt / tau_m) + ( Rm * dt * I / tau_m + Vm[i-1] ) + ( dt * deltaT * (np.exp((Vm[i]-firing_treshold)/deltaT)) / tau_m )
            if Vm[i] >= Vth:
                if Vm[i] >= firing_treshold:
                    Vm[i] = V_rest
                else:
                    Vm[i] += V_spike
                t_rest = t + tau_ref
    return time, Vm, IRange

# %% [markdown]
# ### Plot ELIF

# %%
def plot_elif(model):
    [time, Vm, _] = model
    # plot membrane potential trace
    plt.plot(time, Vm)
    plt.title('Exponentially Leaky Integrate-and-Fire')
    plt.ylabel('U(V)')
    plt.xlabel('Time (msec)')
    plt.show()

# %% [markdown]
# ### Dwar I - T Plot

# %%
def plot_i_t(model):
    [time, _, IRange] = model
    plt.plot(time, IRange)
    plt.title('I and Time')
    plt.ylabel('I(A)')
    plt.xlabel('Time (msec)')
    plt.show()

# %% [markdown]
# ### Create Model

# %%
T = 50 # total time to simulate (msec)
dt = 0.125 # simulation time step (msec)
time = np.arange(0, T+dt, dt) # time array
t_rest = 0 # initial refractory time
Rm = 1 # resistance (kOhm)
Cm = 10 # capacitance (uF)
tau_ref = 4 # refractory period (msec)
Vth = 1 # spike threshold (V)
firing_treshold = 2
V_spike = 0.5 # spike delta (V)
I = 1.5 # input current (A)
V_rest = 0.2
deltaT = 0.001

model = e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT,  I )

# %%
plot_elif(model)

# %%
plot_i_t(model)

# %%
model_alt = e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT, Alternative=True, startRange=1, endRange=5)

# %%
plot_elif(model_alt)

# %%
plot_i_t(model_alt)

# %% [markdown]
# When **I** is Increased in each Iteration (0.5 A)

# %%
T = 50
dt = 0.125
time = np.arange(0, T+dt, dt)
t_rest = 0 
Rm = 1 
Cm = 10
tau_ref = 4 
Vth = 1
firing_treshold = 2
V_spike = 0.5 
I = 1.5 
V_rest = 0.2
deltaT = 0.001
tau_m = Rm*Cm
Vm = np.zeros(len(time))
IRange = []

for i, t in enumerate(time):
    I += 0.5
    if t > t_rest:
        Vm[i] = ( - ( Vm[i] - Vm[i-1] ) * dt / tau_m) + ( Rm * dt * I / tau_m + Vm[i-1] ) + ( dt * deltaT * (np.exp((Vm[i]-firing_treshold)/deltaT)) / tau_m )
    if Vm[i] >= Vth:
        if Vm[i] >= firing_treshold:
            Vm[i] = V_rest
        else:
            Vm[i] += V_spike
        t_rest = t + tau_ref

    
# plot membrane potential trace
plt.plot(time, Vm)
plt.title('Exponentialy Leaky Integrate-and-Fire')
plt.ylabel('U(v)')
plt.xlabel('Time (msec)')
plt.show()

# %% [markdown]
# ### Create Model_2

# %%
T = 100 # total time to simulate (msec)
dt = 0.125 # simulation time step (msec)
time = np.arange(0, T+dt, dt) # time array
t_rest = 0 # initial refractory time
Rm = 1 # resistance (kOhm)
Cm = 10 # capacitance (uF)
tau_ref = 2 # refractory period (msec)
Vth = 2 # spike threshold (V)
V_spike = 1.5 # spike delta (V)
I = 3.5 # input current (A)
firing_treshold = 2
V_rest = 0.2
deltaT = 0.001

model = e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT,  I )
plot_elif(model)

# %% [markdown]
# ### Create Model_3

# %%
T = 100 # total time to simulate (msec)
dt = 0.125 # simulation time step (msec)
time = np.arange(0, T+dt, dt) # time array
t_rest = 0 # initial refractory time
Rm = 1 # resistance (kOhm)
Cm = 10 # capacitance (uF)
tau_ref = 2 # refractory period (msec)
Vth = 2 # spike threshold (V)
V_spike = 1.5 # spike delta (V)
I = 5.5 # input current (A)
V_rest = 0.2
deltaT = 0.001

model = e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT,  I )
plot_elif(model)

# %% [markdown]
# ### Create Model_4

# %%
T = 50 # total time to simulate (msec)
dt = 0.125 # simulation time step (msec)
time = np.arange(0, T+dt, dt) # time array
t_rest = 0 # initial refractory time
Rm = 1 # resistance (kOhm)
Cm = 10 # capacitance (uF)
tau_ref = 4 # refractory period (msec)
Vth = 1 # spike threshold (V)
V_spike = 0.5 # spike delta (V)
I = 1.5 # input current (A)
firing_treshold = 2
V_rest = 0.2
deltaT = 0.001

model = e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT,  I )
plot_elif(model)

# %% [markdown]
# ### Create Model_5

# %%
T = 100 # total time to simulate (msec)
dt = 0.125 # simulation time step (msec)
time = np.arange(0, T+dt, dt) # time array
t_rest = 0 # initial refractory time
Rm = 1 # resistance (kOhm)
Cm = 40 # capacitance (uF)
tau_ref = 2 # refractory period (msec)
Vth = 2 # spike threshold (V)
V_spike = 0.5 # spike delta (V)
I = 10 # input current (A)
V_rest = 0.2
deltaT = 0.001

model = e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT,  I )
plot_elif(model)

# %% [markdown]
# ### model_alt_2

# %%
T = 100 # total time to simulate (msec)
dt = 0.125 # simulation time step (msec)
time = np.arange(0, T+dt, dt) # time array
t_rest = 0 # initial refractory time
Rm = 1 # resistance (kOhm)
Cm = 10 # capacitance (uF)
tau_ref = 1 # refractory period (msec)
Vth = 2 # spike threshold (V)
V_spike = 0 # spike delta (V)
I = 0.5 # input current (A)
V_rest = 0.2
deltaT = 0.001


model_alt_2 = e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT, Alternative=True, startRange=5, endRange=10)
plot_elif(model_alt_2)

# %% [markdown]
# ### model_alt_3

# %%
T = 100 # total time to simulate (msec)
dt = 0.125 # simulation time step (msec)
time = np.arange(0, T+dt, dt) # time array
t_rest = 0 # initial refractory time
Rm = 1 # resistance (kOhm)
Cm = 15 # capacitance (uF)
tau_ref = 4 # refractory period (msec)
Vth = 2 # spike threshold (V)
V_spike = .5 # spike delta (V)
I = 15 # input current (A)
V_rest = 0.2
deltaT = 0.001

model_alt_3 = e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT, Alternative=True, startRange=5, endRange=10)
plot_elif(model_alt_3)

# %% [markdown]
# ### model_alt_4

# %%
T = 100 # total time to simulate (msec)
dt = 0.125 # simulation time step (msec)
time = np.arange(0, T+dt, dt) # time array
t_rest = 0 # initial refractory time
Rm = 1 # resistance (kOhm)
Cm = 10 # capacitance (uF)
tau_ref = 4 # refractory period (msec)
Vth = 2 # spike threshold (V)
V_spike = 4.5 # spike delta (V)
I = 0 # input current (A)
V_rest = 0.2
deltaT = 0.001

model_alt_2 = e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT, Alternative=True, startRange=5, endRange=10)
plot_elif(model_alt_2)

# %% [markdown]
# ### model_alt_5

# %%
T = 100 # total time to simulate (msec)
dt = 0.125 # simulation time step (msec)
time = np.arange(0, T+dt, dt) # time array
t_rest = 0 # initial refractory time
Rm = 1 # resistance (kOhm)
Cm = 80 # capacitance (uF)
tau_ref = 5 # refractory period (msec)
Vth = 2 # spike threshold (V)
V_spike = .5 # spike delta (V)
I = 9 # input current (A)
V_rest = 0.2
deltaT = 0.001

model_alt_2 = e_lif_model(time, t_rest, Rm, Cm, tau_ref, Vth, firing_treshold, V_spike, V_rest, deltaT, Alternative=True, startRange=5, endRange=10)
plot_elif(model_alt_2)
